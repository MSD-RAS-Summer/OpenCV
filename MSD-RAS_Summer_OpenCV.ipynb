# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# Clone Repository from Github

# %%
import os
 
# %cd /content/drive/MyDrive/
if os.path.isdir("/content/drive/MyDrive/MSD-RAS_OpenCV"):
    # %cd /content/drive/MyDrive/MSD-RAS_OpenCV/
else:
    # %cd /content/drive/MyDrive
    # !mkdir MSD-RAS_OpenCV
    # !git clone https://github.com/MSD-RAS-Summer/OpenCV
    # %cd /content/drive/MyDrive/CV/

# %% [markdown]
# # **Grayscale**

# %% [markdown]
# Converts input image to grayscale | Saves to location of input image

# %%
# !python grayscale.py --input "insert/path/here"

# %% [markdown]
# # **Resized**

# %% [markdown]
# Resizes input image based on width and height | Saves to location of input image

# %%
# !python resize.py --input "insert/path/here" --width 120 height 120

# %% [markdown]
# # **Rotated**

# %% [markdown]
# Rotates input image Clockwise 90 degrees | Saves to location of input image

# %%
# !python rotate.py --input "insert/path/here"

# %% [markdown]
# # **Cropped**

# %% [markdown]
# Crops input image based on width and height | Saves to location of input image

# %%
# !python cropped.py --input "insert/path/here" --width 120 height 120

# %% [markdown]
# # **Threshold**

# %% [markdown]
# Converts input image to adaptive threshold - default values
# "!python threshold.py --input "path" --kernel 11 --constant 4" | Saves to location of input image

# %%
# !python threshold.py --input "insert/path/here" --kernel 11 --constant 4

# %% [markdown]
# # **Contour**

# %% [markdown]
# Draws Edge Contours on input image - default values
# "!python contour.py --input "path" --min 220 --max 240 --thickness 2" | Saves to location of input image

# %%
# !python contour.py --input "insert/path/here" --min 220 --max 240 --thickness 2

# %% [markdown]
# # **Canny**

# %% [markdown]
# Converts input image to an edge representation using the Canny Edge Detection Method - default values
# "!python canny.py --input "path" --blur 5 --aperture 3" | Saves to location of input image

# %%
# !python canny.py --input "insert/path/here" --blur 5 aperture 3

# %% [markdown]
# # **Color Swap**

# %% [markdown]
# Converts input image 1 to the colorspace of input image 2 | Saves to location of input image

# %%
# !python colorswap.py --input1 "insert/path/here" --input2 "insert/path/here"
